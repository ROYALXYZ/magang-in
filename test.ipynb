# %%
import pandas as pd

# %%
df_indo = pd.read_csv("data/magangin_jobs_cleaned.csv")
df_indo
# Out:
#         source                                              title  \
# 0    jobstreet                                 Software Developer
# 1    jobstreet                           Junior Software Engineer
# 2    jobstreet                            Full Stack AI Developer
# 3    jobstreet                                 Backend Programmer
# 4    jobstreet                       Software Engineer Internship
# ..         ...                                                ...
# 184  jobstreet                             AI Engineer Specialist
# 185  jobstreet  Intern Care Officer (IT Support & Customer Ser...
# 186  jobstreet                                  IT Support Intern
# 187  jobstreet                            IT Support - Internship
# 188  jobstreet                                       DATA ANALYST
#
#                                          link  \
# 0    https://id.jobstreet.com/id/job/91908572
# 1    https://id.jobstreet.com/id/job/91648206
# ...

# %%
df_global = pd.read_csv("data/global_jobs_cleaned.csv")
df_global
# Out:
#               title    company_name  \
# 0    .NET Developer  Global Company
# 1    .NET Developer  Global Company
# 2    .NET Developer  Global Company
# 3    .NET Developer  Global Company
# 4    .NET Developer  Global Company
# ..              ...             ...
# 713   Web Developer  Global Company
# 714   Web Developer  Global Company
# 715   Web Developer  Global Company
# 716   Web Developer  Global Company
# 717   Web Developer  Global Company
#
#                                                 skills         location_city  \
# 0    C#; VB.NET basics; .NET Framework; .NET Core f...  Remote/International
# 1    C#; .NET Framework basics; ASP.NET; Razor; HTM...  Remote/International
# 2    C#; VB.NET basics; .NET Core; ASP.NET MVC; HTM...  Remote/International
# 3    C#; .NET Framework; ASP.NET basics; SQL Server...  Remote/International
# 4    C#; ASP.NET; MVC; Entity Framework basics; SQL...  Remote/International
# ...

# %%
from jcopml.plot import plot_missing_value

# %%
df_indo.head()
# Out:
#       source                         title  \
# 0  jobstreet            Software Developer
# 1  jobstreet      Junior Software Engineer
# 2  jobstreet       Full Stack AI Developer
# 3  jobstreet            Backend Programmer
# 4  jobstreet  Software Engineer Internship
#
#                                        link                 company_name  \
# 0  https://id.jobstreet.com/id/job/91908572       PT Swadharma Duta Data
# 1  https://id.jobstreet.com/id/job/91648206  PT Technet Vision Indonesia
# 2  https://id.jobstreet.com/id/job/91502813  PT Kharsima Alpha Teknologi
# 3  https://id.jobstreet.com/id/job/92000167          PT Nutech Integrasi
# 4  https://id.jobstreet.com/id/job/91761487               OPPO Indonesia
#
#                                               skills  skills_count  \
# 0  agile, android, angular, api, aws, ci/cd, cicd...            27
# 1  agile, angular, api, aws, cicd, css, docker, g...            20
# ...

# %%
df_indo.shape
# Out:
# (189, 10)

# %%
plot_missing_value(df_indo)

# %%
df_indo
# Out:
#         source                                              title  \
# 0    jobstreet                                 Software Developer
# 1    jobstreet                           Junior Software Engineer
# 2    jobstreet                            Full Stack AI Developer
# 3    jobstreet                                 Backend Programmer
# 4    jobstreet                       Software Engineer Internship
# ..         ...                                                ...
# 184  jobstreet                             AI Engineer Specialist
# 185  jobstreet  Intern Care Officer (IT Support & Customer Ser...
# 186  jobstreet                                  IT Support Intern
# 187  jobstreet                            IT Support - Internship
# 188  jobstreet                                       DATA ANALYST
#
#                                          link  \
# 0    https://id.jobstreet.com/id/job/91908572
# 1    https://id.jobstreet.com/id/job/91648206
# ...

# %%
plot_missing_value(df_global)

# %%
test = df_indo[df_indo['skills'].isna()]['title']
for i in test.unique():
    print(i)

# %%
df_indo['skills'].isna().value_counts()
# Out:
# skills
# False    189
# Name: count, dtype: int64

# %%
df_indo[df_indo['company_name'] == 'Unknown']
# Out:
#         source                                     title  \
# 112  jobstreet  Lowongan Kerja UI/UX Designer Internship
# 118  jobstreet          Network Security Department Head
# 126  jobstreet                    Cyber Security Officer
# 183  jobstreet                             Data Engineer
#
#                                          link company_name  \
# 112  https://id.jobstreet.com/id/job/90477881      Unknown
# 118  https://id.jobstreet.com/id/job/91803680      Unknown
# 126  https://id.jobstreet.com/id/job/91887796      Unknown
# 183  https://id.jobstreet.com/id/job/91978016      Unknown
#
#                                                 skills  skills_count   role  \
# 112       adobexd, design system, figma, user research             4  ui/ux
# 118  network security, penetration, security, wires...             4  cyber
# 126  network security, penetration, security, wires...             4  cyber
# ...
